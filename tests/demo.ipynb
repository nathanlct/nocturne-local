# %%
import numpy as np
import matplotlib.pyplot as plt

from nocturne import Simulation

# %%
sim = Simulation(scenarioPath='../scenarios/intersection.json')
scenario = sim.getScenario()

# %%
objects = scenario.getRoadObjects()
print(objects)

veh = objects[-1]
# Out:
# [<nocturne.Object object at 0x7fde9c20a4f0>, <nocturne.Object object at 0x7fde9c204fb0>, <nocturne.Object object at 0x7fde9c204230>, <nocturne.Object object at 0x7fde9c204270>, <nocturne.Object object at 0x7fde9c204d70>, <nocturne.Object object at 0x7fde9c2042b0>, <nocturne.Object object at 0x7fde9c204d30>, <nocturne.Object object at 0x7fde9c204eb0>, <nocturne.Vehicle object at 0x7fde9c204bf0>]

# %%
coneImages = []
goalImages = []
n = 20

for i in range(n):
    coneImg = np.array(scenario.getCone(veh, 3.14/2.0, 0.0), copy=False)
    coneImages.append(coneImg)
    
    goalImg = np.array(scenario.getGoalImage(veh), copy=False)
    goalImages.append(goalImg)
    
    veh.setAccel(20.0 if i <= 8 else 0.0)
    veh.setSteeringAngle(-12. * 3.1415 / 180.0 if i >= 6 and i <= 9 else 0)
    
    for _ in range(5): # 0.5s
        sim.step(0.1)
# Out:
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!
# collision!

# %%
plt.figure()


fig, axes = plt.subplots(n, 2, figsize=(15, n * 7.5)) 

for i in range(n):
    axes[i][0].imshow(coneImages[i])
    axes[i][1].imshow(goalImages[i])
